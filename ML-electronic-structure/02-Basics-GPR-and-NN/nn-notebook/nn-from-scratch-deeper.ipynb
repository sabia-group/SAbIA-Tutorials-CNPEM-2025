# %% [markdown]
# # 2. Neural Network - hands on implementation

# %% [markdown]
# This notebook contains a simple, from scratch implementation of a neural network using only Numpy. In this notebook we will try to learn a simple 1D Morse potential using an arbitrary amount of neurons and layers.
#
# An insightful visual introduction on NNs is the series by 3blue1brown that can be found [here](https://www.3blue1brown.com/topics/neural-networks).
#
# Stable and effective implementations of NNs are available, for example, in the [pytorch](https://pytorch.org) package.

# %% [markdown]
# ## 2.1 Libraries (minimal)

# %%
import numpy as np
import plotly.graph_objects as go
import matplotlib.pyplot as plt
import ipywidgets as widgets
from IPython.display import display, clear_output

# %% [markdown]
# ## 2.2 Neural Networks & Activation Functions
#
# A **neural network** is a computational model constructed as layers of interconnected units (neurons) that learn to approximate complex functions from input data.
#
# Each neuron applies a weighted sum to its inputs and passes the result through a **non-linear activation function**:
#
# 1. Compute a **weighted sum** of inputs:
#     $$
#     z = \sum_{i} w_i x_i + b = \mathbf{w}^\top \mathbf{x} + b
#     $$
# 2. Apply a **nonlinear activation function**:
#    $$
#    a = \sigma(z)
#    $$
#
# These functions are essential for enabling the network to model non-linear relationships. This output $a$ becomes input to the next layer (or is the final prediction if this is the output layer).
#
# One of the earliest used activation function was the **sigmoid**:
#
# $$
# \sigma(z) = \frac{1}{1 + e^{-z}} \quad  \sigma'(z) = \sigma(z)(1 - \sigma(z))
# $$
#
# It maps inputs to the range (0, 1), making it useful for outputs interpreted as probabilities. Historically, sigmoid was favored for its smoothness and differentiability, which made it suitable for training via gradient descent. While less common today, it's an important starting point.

# %%
def sigmoid(x):
    return 1 / (1 + np.exp(-x))

def sigmoid_deriv( x):
    s = sigmoid(x)
    return s * (1 - s)

xgrid=np.arange(-10,10,0.1)
a=[sigmoid(x) for x in xgrid]
plt.plot(xgrid, a)
plt.show()

# %% [markdown]
# ## 2.3 Initializing the NN architechture
# When scaling neural networks, two key design decisions are:
#
# - **Wider**: more neurons per layer
# - **Deeper**: more layers stacked sequentially
#
# **Wider**:
#
# In a **wider network**, a single layer outputs a vector of multiple activations: A **wider layer** with $m$ neurons computes:
# $$
# \mathbf{z} = \mathbf{W} \mathbf{x} + \mathbf{b}, \quad \mathbf{a} = \sigma(\mathbf{z})
# $$
#
# where:
# - $ \mathbf{x} \in \mathbb{R}^n $ input vector
# - $ \mathbf{W} \in \mathbb{R}^{m \times n} $ (weights matrix)
# - $ \mathbf{b} \in \mathbb{R}^m $ (bias vector)
# - $ \sigma $ is applied elementwise
#
# So the layer acts as a function:
# $$
# \mathbb{R}^n \rightarrow \mathbb{R}^m
# $$
#
# The layer outputs a **vector of activations**, i.e., multiple neurons firing in parallel.
#
#
# **Deeper**:
#
# A **deeper network** stacks layers sequentially. Each layer transforms the output of the previous layer:
#
# $$
# f(\mathbf{x}) = \sigma^{(3)} \left( \mathbf{W}^{(3)} \cdot \sigma^{(2)} \left( \mathbf{W}^{(2)} \cdot \sigma^{(1)} \left( \mathbf{W}^{(1)} \mathbf{x} + \mathbf{b}^{(1)} \right) + \mathbf{b}^{(2)} \right) + \mathbf{b}^{(3)} \right).
# $$

# %%
def initialize_network(learning_rate, num_layers, num_neurons):
    params = {
        'learning_rate': learning_rate,
        'num_layers': num_layers,
        'num_neurons': num_neurons,
        'weights': [],
        'biases': []
    }

    # Input to first hidden layer
    params['weights'].append(np.random.randn(num_neurons))  # shape: (num_neurons,)
    params['biases'].append(np.random.randn(num_neurons))

    # Hidden layers
    for _ in range(num_layers - 1):
        params['weights'].append(np.random.randn(num_neurons, num_neurons))
        params['biases'].append(np.random.randn(num_neurons))

    # Output layer
    params['output_weights'] = np.random.randn(num_neurons)
    params['output_bias'] = np.random.randn()

    return params

# %% [markdown]
# ### 2.3.1 Prediction

# %%
def predict(params, x):
    a = x
    activations = []
    zs = []

    # Input to first hidden
    z = params['weights'][0] * a + params['biases'][0]
    zs.append(z)
    a = sigmoid(z)
    activations.append(a)

    # Hidden layers
    for i in range(1, params['num_layers']):
        z = np.dot(params['weights'][i], a) + params['biases'][i]
        zs.append(z)
        a = sigmoid(z)
        activations.append(a)

    # Output layer (linear)
    output = np.dot(params['output_weights'], a) + params['output_bias']
    return output

# %% [markdown]
# ## 2.4 Training and backpropagating through SGD
#
# To train a neural network, we minimize a loss function — typically Mean Squared Error (MSE) for regression problems. The model learns by adjusting its weights and biases through a process called **backpropagation**. Training in this example is done using **stochastic gradient descent (SGD)**: a single random training point is used to update the model weights at each iteration. An entire round of updates is called an **epoch**.
#
# The goal is to minimize the difference between the predicted output $\hat{y}$ and the true target $y$:
#
# $$
# \mathcal{L} = (\hat{y} - y)^2
# $$
#
# The output prediction is:
# $$
# \hat{y} = W_{\text{out}} \cdot a + b_{\text{out}}.
# $$
#
# Let’s take one layer for illustration. The activation $a$ comes from:
#
# - Activation:
#   $$
#   a = \sigma(z)
#   $$
#
# - Pre-activation:
#   $$
#   z = W \cdot a_{\text{prev}} + b
#   $$

# %% [markdown]
# Now suppose we want $ \frac{\partial \mathcal{L}}{\partial W} $, i.e., how changing the weights affects the loss. We can do so via a convenient chain-rule:
#
# **Step-by-step:**
# 1. Loss depends on output
# 2. Output depends on activation
# 3. Activation depends on pre-activation
# 4. Pre-activation depends on weights

# %% [markdown]
# Putting it together:
#
# $$
# \frac{\partial \mathcal{L}}{\partial W} = \frac{\partial \mathcal{L}}{\partial \hat{y}} \cdot \frac{\partial \hat{y}}{\partial a} \cdot \frac{\partial a}{\partial z} \cdot \frac{\partial z}{\partial W}
# $$
#
# This gives a recipe for computing **gradients layer by layer**, starting from the output and going backward. This is why it’s called **back-propagation**. The same goes for the biases.
#
# - For each layer, update:
#
#   - Weights:
#     $$
#     W \leftarrow W - \eta \cdot \frac{\partial \mathcal{L}}{\partial W}
#     $$
#   - Biases:
#     $$
#     b \leftarrow b - \eta \cdot \frac{\partial \mathcal{L}}{\partial b}
#     $$
#
# This process continues layer by layer, back through the network — hence the name **backpropagation**. The hyperparameter $\eta$ is called **learning rate** and controls the magnitude of these updates.

# %%
def train(params, input_vectors, targets, iterations, progress_callback=None):
    cumulative_errors = []
    for current_iteration in range(iterations):
        idx = np.random.randint(len(input_vectors))
        x = input_vectors[idx]
        y = targets[idx]

        compute_gradients(params, x, y)

        if current_iteration % 100 == 0:
            total_error = 0
            for i in range(len(input_vectors)):
                pred = predict(params, input_vectors[i])
                error = np.square(pred - targets[i])
                total_error += error
            cumulative_errors.append(total_error)
        
        if progress_callback is not None:
            # Call progress update every, say, 1000 epochs or on last epoch
            if current_iteration % 1000 == 0 or current_iteration == iterations - 1:
                progress_callback(current_iteration + 1)

    return cumulative_errors

# Will use this to store training history later
training_history = {}

# %%
def compute_gradients(params, x, target):
    a = x
    activations = []
    zs = []

    # Forward pass
    z = params['weights'][0] * a + params['biases'][0]
    zs.append(z)
    a = sigmoid(z)
    activations.append(a)

    for i in range(1, params['num_layers']):
        z = np.dot(params['weights'][i], a) + params['biases'][i]
        zs.append(z)
        a = sigmoid(z)
        activations.append(a)

    output = np.dot(params['output_weights'], a) + params['output_bias']

    # Loss derivative
    derror_doutput = 2 * (output - target)

    # Gradients for output layer
    doutput_dweights = activations[-1]
    derror_doutput_weights = derror_doutput * doutput_dweights
    derror_doutput_bias = derror_doutput

    # Backprop into last hidden layer
    delta = derror_doutput * params['output_weights']
    for i in reversed(range(params['num_layers'])):
        z = zs[i]
        a_deriv = sigmoid_deriv(z)
        delta *= a_deriv

        a_prev = x if i == 0 else activations[i - 1]

        dW = np.outer(delta, a_prev) if i > 0 else delta * a_prev
        db = delta

        # Update weights and biases
        params['weights'][i] -= params['learning_rate'] * dW
        params['biases'][i] -= params['learning_rate'] * db

        if i > 0:
            delta = np.dot(params['weights'][i].T, delta)

    # Update output weights
    params['output_weights'] -= params['learning_rate'] * derror_doutput_weights
    params['output_bias'] -= params['learning_rate'] * derror_doutput_bias

# %% [markdown]
# ## 2.5 Initializing training data

# %%
fulldata = np.loadtxt('dists-energies/combineddata.dat')
fullx = fulldata.T[0]
fully = fulldata.T[1]
zero=np.min(fully)
fully=fully-zero
plt.scatter(fullx, fully)
#zero=fully[-1]
# manipulate data like minmax
fullynew = fully
fullxnew = fullx
#scaling
scaley=np.max(fullynew)
scalex=np.max(fullxnew)
fullynew=fullynew/scaley
fullxnew=fullxnew/scalex
plt.ylabel('energy (eV)', fontsize=14)
plt.xlabel('distance (A)', fontsize=14)
# Out:
# Text(0.5, 0, 'distance (A)')

# %% [markdown]
# ### 2.5.1 Selecting training set with FPS
#
# The variable `nsamples` controls how many training points are selected from the full dataset using Farthest Point Sampling (FPS). In the previous tutorial, we used Gaussian Process Regression (GPR), a non-parametric method where both training and prediction become computationally expensive as the training set grows. In contrast, **NNs are parametric models**: while training with more data takes longer, the prediction speed remains fast and independent of the training set size. This allows us to use larger training sets with NNs than with GPR, especially when leveraging efficient sampling strategies like FPS.

# %%
def simple_fps(datax, nsamples):
    n = len(datax)
    distances = np.full(n, 1e10)
    sampled = np.zeros(nsamples, dtype=int)

    index = np.random.choice(n, 1, replace=False).item()  # Extract scalar
    sampled[0] = index

    for i in range(1, nsamples):  # Start from 1 because first index is already sampled
        for j in range(n):
            dist = np.abs(datax[j] - datax[index])
            if dist <= distances[j]:
                distances[j] = dist
        index = np.argmax(distances)
        sampled[i] = index

    return sampled

# Define the number of samples
nsamples = 50

# Check if nsamples is not greater than the length of the array
if nsamples > len(fullxnew):
    raise ValueError("nsamples cannot be greater than the length of the array.")

# Call fps
indices = simple_fps(fullxnew, nsamples)
selected_x_fps = fullxnew[indices]
selected_y_fps = fullynew[indices]

input_vectors = selected_x_fps[:np.newaxis]
targets = selected_y_fps[:np.newaxis]

x_values=selected_x_fps
y_values=selected_y_fps
plt.figure(figsize=(8, 5))
plt.xlim([0.0,1])
plt.ylabel('energy (eV, scaled)', fontsize=14)
plt.xlabel('distance (A, scaled)', fontsize=14)
plt.yticks(fontsize=12)
plt.xticks(fontsize=12)
plt.scatter(x_values, y_values, marker='o', s=50)
plt.scatter(fullxnew, fullynew, marker='o', s=10)
plt.show()

# %% [markdown]
# ## 2.6 Neural Network Behavior
#
# Use the sliders and "Train" button to explore how different hyperparameters and architechtures affect neural network training. Name each run for future comparison. You can clear all the previous runs by clicking on "Clear All History". Re-running the following cell will not delete the history.
#
# Below are some suggested exercises exploring different features and limitations of this simple NN we constructed.

# %%
num_layers_slider = widgets.IntSlider(value=2, min=1, max=5, step=1, description='Layers:')
num_neurons_slider = widgets.IntSlider(value=50, min=1, max=300, step=5, description='Neurons:')
learning_rate_slider = widgets.FloatLogSlider(value=0.001, base=10, min=-5, max=0, step=0.1, description='LR:')
epochs_slider = widgets.IntSlider(value=50000, min=1000, max=1000000, step=1000, description='Epochs:')
clear_all_button = widgets.Button(description="Clear All History", button_style='danger')



run_name_input = widgets.Text(
    value='',
    placeholder='Enter run name',
    description='Run Name:',
    disabled=False
)

progress_bar = widgets.IntProgress(
    value=0,
    min=0,
    max=epochs_slider.value,
    description='Training:',
    style={'description_width': 'initial'},
    orientation='horizontal'
)

status_label = widgets.Label(value='')

train_button = widgets.Button(description="Train")
output = widgets.Output()

def update_progress_bar(epoch):
    progress_bar.value = epoch

def on_train_button_clicked(b):
    output.clear_output(wait=True)
    with output:
        run_name = run_name_input.value.strip()
        if not run_name:
            print("Please enter a run name before training.")
            return
        
        if run_name in training_history:
            print(f"Warning: Run name '{run_name}' already exists. Overwriting the previous run.")

        status_label.value = f"⏳ Training '{run_name}' in progress..."
        progress_bar.max = epochs_slider.value
        progress_bar.value = 0
        progress_bar.bar_style = ''

        params = initialize_network(
            learning_rate_slider.value,
            num_layers_slider.value,
            num_neurons_slider.value
        )

        errors = train(params, input_vectors, targets,
                       iterations=epochs_slider.value,
                       progress_callback=update_progress_bar)

        fig, axs = plt.subplots(1, 2, figsize=(12, 5))
        
        xgrid = np.arange(0, 1, 0.01)
        ypred = np.array([predict(params, xi) for xi in xgrid])

        # Plot training loss (log-log scale)
        axs[0].plot(errors)
        axs[0].set_yscale('log')
        axs[0].set_xscale('log')
        axs[0].set_title("Training Loss")
        axs[0].set_xlabel("Iterations (log)")
        axs[0].set_ylabel("MSE Loss (log)")

        # Plot prediction fit
        axs[1].plot(xgrid * scalex, ypred * scaley, label="Prediction")
        axs[1].scatter(fullx, fully, s=10, alpha=0.5, label="True data")
        axs[1].set_title("NN Fit")
        axs[1].set_xlabel("Distance (Å)")
        axs[1].set_ylabel("Energy (eV)")
        axs[1].legend()
        axs[1].set_ylim(-2, 20)

        plt.tight_layout()
        plt.show()
        plt.close(fig)

        run_data = {
            "layers": num_layers_slider.value,
            "neurons": num_neurons_slider.value,
            "lr": learning_rate_slider.value,
            "epochs": epochs_slider.value,
            "pred": ypred,
            "error_curve": errors
        }
        training_history[run_name] = run_data

        progress_bar.bar_style = 'success'
        status_label.value = "✅ Training complete!"
    return

train_button.on_click(on_train_button_clicked)

def on_clear_all_button_clicked(b):
    with output:
        clear_output(wait=True)
        training_history.clear()
        status_label.value = "Cleared all training history."

clear_all_button.on_click(on_clear_all_button_clicked)


ui = widgets.VBox([
    run_name_input,
    num_layers_slider,
    num_neurons_slider,
    learning_rate_slider,
    epochs_slider,
    widgets.HBox([train_button, clear_all_button]),
    progress_bar,
    status_label,
    output
])

display(ui)
# Out:
# VBox(children=(Text(value='', description='Run Name:', placeholder='Enter run name'), IntSlider(value=2, descr…

# %% [markdown]
# ### 2.6.1 Exercises:
#
# #### a) **Underfitting**
# - **Suggested setup range:**
#   - Layers: `1`
#   - Neurons: `1–3`
#   - Learning Rate: `0.001`
#   - Epochs: `up to 1000000`
# - **What to look for:**
#   Loss decreases slowly or stalls, and the predictions remain overly simple — the model fails to capture complexity. If you chose a single neuron, can you think of which functions (if any) our simple NN could successfully fit?
#
#
# #### b) **Too low learning rate**
# - **Suggested setup range:**
#   - Layers: `1-2`
#   - Neurons: `10–50`
#   - Learning Rate: `0.00001`
#   - Epochs: `400000–800000`
# - **What to look for:**
#   Loss drops very slowly or flattens out early, indicating ineffective learning progress.
#
#
# #### c) **Too high learning rate**
# - **Suggested setup range:**
#   - Layers: `2`
#   - Neurons: `10–50`
#   - Learning Rate: `0.1 – 1.0`
#   - Epochs: `50000–150000`
# - **What to look for:**
#   Training loss is unstable or even increases. Predictions jump around due to overly large updates. Weights might explode (overflow in sigmoid).
#
#   ⚠️ Note: In this simplified neural network (trained with manual code and no adaptive optimizers), a higher learning rate may sometimes appear to "work better". With a very low learning rate, convergence can be extremely slow, and the network may appear "stuck" unless trained for hundreds of thousands or even millions of epochs. This is due to the absence of momentum, weight decay (regularization), or adaptive methods like Adam — so higher learning rates may be needed to escape flat regions or poor local minima. However, this comes at the cost of instability or chaotic behavior if the learning rate is too large.
#
#
# #### d) **Just right (for us)**
# - **Suggested setup range:**
#   - Layers: `1-2`
#   - Neurons: `15–150`
#   - Learning Rate: `0.001 - 0.05`
#   - Epochs: `tune based on LR, 500000 - 800000`
# - **What to look for:**
#   Predictions are finally more accurate. Once you found a good architecture, try running the training a few times without adjusting anything, simply change the name to "Right1", "Right2", etc. and plot everything in the last cell of this notebook (down below). This should highlight the non-deterministic nature of the training process. Due to the random initialization of the parameters, the NN learns slightly different every time. This is at the basis of committee models, that you will see in our third tutorial.
#
#
# #### e) **Wide vs Deep**
# - **Suggested action:**
#   Try comparing a shallow-wide network to a deep-narrow network with a similar total number of parameters.
#   - **Example A (Wide):** Layers: `1`, Neurons: `100`
#   - **Example B (Deep):** Layers: `4`, Neurons: `25`
#   - Learning Rate: `0.01-0.05`
#   - Epochs: `300000–600000`
# - **What to look for:**
#    Wide models may memorize faster; deep models may capture "hierarchical" patterns. Common MLIPs are usually shallow networks: the physical features are already cleverly encoded into descriptors for the input features, reducing the need of abstraction ("depth") in the model itself. In this simple case, a deeper network might work better.
#
#
# #### I) **Compare multiple architectures**
# - **Suggested action:**
#   - Run multiple models with different sizes and learning rates. You can clear the training history at any time by clicking on **"Clear All History"**.
#   - Use the **name field** before clicking **"Train"** to store each run.
#   - Plot all saved predictions and loss curves from history in the cell below.
# - **What to look for:**
#   Compare convergence speed, overfitting/underfitting tendencies, and prediction smoothness across models.
#
# #### II) **Overfitting**
# - **Suggested setup range:**
#   Hard to tell. Try with a lot of parameters, can try to increase LR but it might lead to weights explosion (overflow error in sigmoid). If you have time you can just make the network really big and increase the training time. You might still not achieve overfitting in this simple scenario and with limited time.
# - **What to look for:**
#   Predictions may fit training points too closely but behave erratically between them. The model has too many degrees of freedom and has no bias towards "smooth" functions. Hence, any weights and biases that minimize the loss at the training points is as good, including the ones that do crazy stuff between them.

# %% [markdown]
# ### 2.6.2 Plotting entire training history

# %%
fig, axs = plt.subplots(3, 1, figsize=(6, 14))
xgrid = np.arange(0, 1, 0.01)

# --- Plot 1: Full prediction ---
for run_name, run_data in training_history.items():
    axs[0].plot(xgrid * scalex, run_data["pred"] * scaley, label=run_name)

axs[0].scatter(fullx, fully, s=20, alpha=0.5, label="True data")
axs[0].set_title("Model Predictions")
axs[0].set_xlabel("Distance (Å)")
axs[0].set_ylabel("Energy (eV)")
axs[0].legend(fontsize=10)

# --- Plot 2: Zoomed-in prediction (x from 0.4 to 1.5) ---
for run_name, run_data in training_history.items():
    axs[1].plot(xgrid * scalex, run_data["pred"] * scaley, label=run_name)

axs[1].set_xlim(0.4, 1.5)
axs[1].set_title("Zoomed Predictions (0.4–1.5 Å)")
axs[1].set_xlabel("Distance (Å)")
axs[1].set_ylabel("Energy (eV)")
axs[1].set_ylim(-1, 7)
axs[1].legend(fontsize=10)

# --- Plot 3: Training error curves ---
for run_name, run_data in training_history.items():
    axs[2].plot(run_data["error_curve"], label=run_name)

axs[2].set_title("Training Error Curves")
axs[2].set_yscale("log")
axs[2].set_xlabel("Iterations/100")
axs[2].set_ylabel("MSE Loss")
axs[2].legend(fontsize=8)

plt.tight_layout()
plt.show()
# Out:
# C:\Users\skate\AppData\Local\Temp\ipykernel_20360\2123936578.py:23: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   axs[1].legend(fontsize=10)
# C:\Users\skate\AppData\Local\Temp\ipykernel_20360\2123936578.py:33: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   axs[2].legend(fontsize=8)
